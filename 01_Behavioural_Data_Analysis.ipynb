# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from Scripts import behaviour
import os
import numpy as np
import psignifit as ps

# %%
## Plot Psychometrics and Reaction times for group average data
path = r'C:\Users\Brandon\Desktop\PhD\Gated Accumulation\Data'
groupData = behaviour.combineBehaviour(path, all_key = True, subj_key = 'nan', polarity_key = 'nan', exp_key = 'nan')

# %%
behaviour.plotPsycDelays(groupData, 5)
plt.title('Psychometrics by Delay Interval')
# Out:
# Text(0.5, 1.0, 'Psychometrics by Delay Interval')

# %%
behaviour.plotPsycHistory(groupData, 5, 'Rep Number')
behaviour.plotPsycHistory(groupData, 5, 'Alt Number')

# %%
behaviour.plotRTHistory(groupData, 5, 'Rep Number')
behaviour.plotRTHistory(groupData, 5, 'Alt Number')

# %%
behaviour.plotRTDelays(groupData, minDelay = 750, maxDelay = 1200, numBins = 10)

# %%
plt.figure()
plt.hist(groupData['Rep Number'], bins=range(1, 20))
plt.title('Repetition Histogram')

plt.figure()
plt.hist(groupData['Alt Number'], bins=range(1, 20))
plt.title('Alternation Histogram')
# Out:
# Text(0.5, 1.0, 'Alternation Histogram')
